# %%
from bs4 import BeautifulSoup
import requests
import time
import csv

# %%
#practice with one link for the wikipedia pages
url = "https://en.wikipedia.org/wiki/Activated_charcoal_cleanse"
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
for match in soup.findAll('table', class_="box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove"):
    match.replace_with('')
for mama in soup.findAll('p', class_="mw-empty-elt"):
    mama.replace_with('')
table = soup.find_all('table')
info = table[0]
para = soup.find_all('p')
print(para[0].text)
rows = info.find_all('tr')
print(rows[0].text)
ben = soup.find_all( 'td', class_='infobox-data')
print(ben[0].text)
print(ben[1].text)
namez = soup.find('h1')
print(namez.text)
# Out:
# Activated charcoal cleanses, also known as charcoal detoxes, are a pseudoscientific use of a proven medical intervention. Activated charcoal is available in powder, tablet and liquid form. Its proponents claim the use of activated charcoal on a regular basis will detoxify and cleanse the body as well as boost one's energy and brighten the skin. Such claims violate basic principles of chemistry and physiology. There is no medical evidence for any health benefits of cleanses or detoxes via activated charcoal or any other method. Charcoal, when ingested, will absorb vitamins and nutrients as well as prescription medications present in the gastrointestinal tract which can make it dangerous to use unless directed by a medical doctor.
#
# Activated charcoal cleanse
# Detoxification or cleansing of the body
# Activated charcoal can adsorb some prescription medications as well as nutrients present in the stomach if taken shortly after consumption[1]
# Activated charcoal cleanse

# %%
#get the information from all the wikipedia pages
start ="https://en.wikipedia.org/wiki/List_of_forms_of_alternative_medicine"
page = requests.get(start)
soup = BeautifulSoup(page.text, 'html.parser')
from collections import OrderedDict

# %%
#remove the references
for noa in soup.findAll('div', class_="mw-references-wrap"):
    noa.replace_with('')
#remove the empty articles 
for empty in soup.findAll('a', class_="new"):
    empty.replace_with('')
for ci in soup.findAll('sup', class_="noprint Inline-Template Template-Fact"):
    ci.replace_with('')
for contents in soup.findAll('div', class_="toc plainlinks hlist"):
    contents.replace_with('')
for con in soup.findAll('div', class_="navbox"):
    con.replace_with('')
list_list = soup.select('li>a')
for links in list_list:
    link_list = []
    rel = (links.attrs['href'])
    link_list.append(rel)
    res = []
    [res.append(x) for x in link_list if x not in res]
    print(res)
# Out:
# ['/wiki/Activated_charcoal_cleanse']
# ['/wiki/Acupressure']
# ['/wiki/Acupuncture']
# ['/wiki/Affirmative_prayer']
# ['/wiki/Alexander_technique']
# ['/wiki/Alternative_cancer_treatments']
# ['/wiki/Animal-Assisted_Therapy']
# ['/wiki/Anthroposophical_medicine']
# ['/wiki/Apitherapy']
# ['/wiki/Applied_kinesiology']
# ['/wiki/Aquatherapy']
# ['/wiki/Aromatherapy']
# ['/wiki/Art_Therapy']
# ['/wiki/Asahi_Health']
# ['/wiki/Astrology']
# ['/wiki/Attachment_therapy']
# ['/wiki/Auriculotherapy']
# ['/wiki/Autogenic_training']
# ['/wiki/Autosuggestion']
# ['/wiki/Ayurveda']
# ['/wiki/Bach_flower_remedies']
# ['/wiki/Balneotherapy']
# ['/wiki/Bates_method']
# ['/wiki/Bibliotherapy']
# ['/wiki/Biodanza']
# ['/wiki/Bioresonance_therapy']
# ['/wiki/Blood_irradiation_therapies']
martial_arts','/wiki/Massage','/wiki/Medical_intuitive','/wiki/Meditation_(alternative_medicine)','/wiki/Mindfulness_(Buddhism)','/wiki/Vipassana','/wiki/Meridian_(Chinese_medicine)','/wiki/Orthomolecular_medicine','/wiki/Mind%E2%80%93body_intervention','/wiki/Moxibustion','/wiki/Myofascial_release','/wiki/Naprapathy','/wiki/Natural_Health','/wiki/Natural_therapy','/wiki/Naturopathic_medicine','/wiki/New_thought','/wiki/Neuro-linguistic_programming','/wiki/Nutritional_healing','/wiki/Nutritional_supplements','/wiki/Numerology','/wiki/Orthopathy','/wiki/Osteopathy','/wiki/Pilates','/wiki/Prayer','/wiki/Psychic_surgery','/wiki/Prokarin','/wiki/Paula_method','/wiki/Qi','/wiki/Qigong','/wiki/Radionics','/wiki/Rebirthing_(breathwork)','/wiki/Recreational_Therapy','/wiki/Reflexology','/wiki/Reiki','/wiki/Rolfing','/wiki/Rosen_Method','/wiki/Salt_Therapy','/wiki/Self-hypnosis','/wiki/Shiatsu','/wiki/Siddha_medicine','/wiki/Sonopuncture','/wiki/Sound_therapy','/wiki/Spiritual_mind_treatment','/wiki/Structural_Integration','/wiki/Support_groups','/wiki/T%27ai_chi_ch%27uan','/wiki/Tantra_massage','/wiki/Tao_yin','/wiki/Thai_massage','/wiki/Thalassotherapy','/wiki/Therapeutic_horseback_riding','/wiki/Therapeutic_touch','/wiki/Tibetan_eye_chart','/wiki/Traditional_Korean_medicine','/wiki/Traditional_Japanese_medicine','/wiki/Traditional_Mongolian_medicine','/wiki/Traditional_Tibetan_medicine','/wiki/Trager_approach','/wiki/Transcendental_meditation','/wiki/Trigger_point','/wiki/Tui_na','/wiki/Unani_medicine','/wiki/Urine_therapy','/wiki/Uropathy','/wiki/Vaginal_steaming','/wiki/Visualization_(cam)','/wiki/Mental_image','/wiki/Water_cure_(therapy)','/wiki/Wellness_(alternative_medicine)','/wiki/Wuxing_(Chinese_philosophy)','/wiki/Yoga_(alternative_medicine)','/wiki/R%C4%81ja_yoga','/wiki/Ashtanga_vinyasa_yoga','/wiki/Bikram_yoga','/wiki/Hatha_yoga','/wiki/Iyengar_yoga','/wiki/Kundalini_yoga','/wiki/Siddha_yoga','/wiki/Sivananda_yoga','/wiki/Tantric_yoga','/wiki/Viniyoga','/wiki/Vinyasa_yoga','/wiki/Yoga_Therapy','/wiki/Daoyin','/wiki/Zang-fu']

def get_info(page_url):
    page = requests.get( 'https://en.wikipedia.org' + page_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    try:
        for match in soup.findAll('table', class_="box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove"):
            match.replace_with('')
        for mat in soup.findAll('table', class_="box-One_source plainlinks metadata ambox ambox-content ambox-one_source"):
            mat.replace_with('')
        for ma in soup.findAll('table', class_="box-Merge_to plainlinks metadata ambox ambox-move"):
            ma.replace_with('')
        for mama in soup.findAll('p', class_="mw-empty-elt"):
            mama.replace_with('')
        for mam in soup.findAll('sup', class_="reference"):
            mam.replace_with('')
        namez = soup.find('h1')
        print(namez.text)
        table = soup.find_all('table')
        info = table[0]
        rows = info.find_all('tr')
        para = soup.find_all('p')
        print(para[0].text)
        for row in rows:
            try:
                cells = row.find_all('td')
                # print contents of the second cell in the row
                print( cells[1].text )
            except:
                pass
        linkk = ('https://en.wikipedia.org' + page_url)
        print(linkk)
    except:
        print(page_url + ' is missing something!')

# call the function for each URL in the list
for linkzz in link_list:
    get_info(linkzz)
# Out:
# Activated charcoal cleanse
# Activated charcoal cleanses, also known as charcoal detoxes, are a pseudoscientific use of a proven medical intervention. Activated charcoal is available in powder, tablet and liquid form. Its proponents claim the use of activated charcoal on a regular basis will detoxify and cleanse the body as well as boost one's energy and brighten the skin. Such claims violate basic principles of chemistry and physiology. There is no medical evidence for any health benefits of cleanses or detoxes via activated charcoal or any other method. Charcoal, when ingested, will absorb vitamins and nutrients as well as prescription medications present in the gastrointestinal tract which can make it dangerous to use unless directed by a medical doctor.
#
# https://en.wikipedia.org/wiki/Activated_charcoal_cleanse
# Acupressure
# ...

# %%
#csv function 
link_list = ['/wiki/Activated_charcoal_cleanse','/wiki/Acupressure','/wiki/Acupuncture','/wiki/Affirmative_prayer','/wiki/Alexander_technique','/wiki/Alternative_cancer_treatments','/wiki/Animal-Assisted_Therapy','/wiki/Anthroposophical_medicine','/wiki/Apitherapy','/wiki/Applied_kinesiology','/wiki/Aquatherapy','/wiki/Aromatherapy','/wiki/Art_Therapy','/wiki/Asahi_Health','/wiki/Astrology','/wiki/Attachment_therapy','/wiki/Auriculotherapy','/wiki/Autogenic_training','/wiki/Autosuggestion','/wiki/Ayurveda','/wiki/Bach_flower_remedies','/wiki/Balneotherapy','/wiki/Bates_method','/wiki/Bibliotherapy','/wiki/Biodanza','/wiki/Bioresonance_therapy','/wiki/Blood_irradiation_therapies','/wiki/Body_work_(alternative_medicine)','/wiki/Chelation_therapy','/wiki/Chinese_food_therapy','/wiki/Chinese_herbology','/wiki/Chinese_martial_arts','/wiki/Traditional_Chinese_medicine','/wiki/Chinese_pulse_diagnosis','/wiki/Chakra','/wiki/Chiropractic','/wiki/Chromotherapy','/wiki/Colorpuncture','/wiki/Cinema_therapy','/wiki/Coding_(therapy)','/wiki/Gua_Sha','/wiki/Colloidal_silver','/wiki/Colon_cleansing','/wiki/Enema#In_alternative_medicine','/wiki/Craniosacral_therapy','/wiki/Creative_visualization','/wiki/Crystal_healing','/wiki/Fire_cupping','/wiki/Dance_therapy','/wiki/Detoxification_(alternative_medicine)','/wiki/Detoxification_foot_baths','/wiki/Dietary_supplements','/wiki/Dowsing','/wiki/Ear_candling','/wiki/Earthing','/wiki/Eclectic_medicine','/wiki/Electromagnetic_therapy_(alternative_medicine)','/wiki/Electrohomeopathy','/wiki/Equine-assisted_therapy','/wiki/Energy_medicine','/wiki/Magnet_therapy','/wiki/Energy_psychology','/wiki/Faith_healing','/wiki/Fasting','/wiki/Feldenkrais_Method','/wiki/Feng_shui','/wiki/Wuxing_(Chinese_philosophy)','/wiki/Flower_essence_therapy','/wiki/Functional_medicine','/wiki/German_New_Medicine','/wiki/Grahamism','/wiki/Grinberg_Method','/wiki/Gua_sha','/wiki/Graphology','/wiki/Hair_analysis_(
def get_info(page_url):
    page = requests.get( 'https://en.wikipedia.org' + page_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    try:
        for match in soup.findAll('table', class_="box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove"):
            match.replace_with('')
        for mat in soup.findAll('table', class_="box-One_source plainlinks metadata ambox ambox-content ambox-one_source"):
            mat.replace_with('')
        for ma in soup.findAll('table', class_="box-Merge_to plainlinks metadata ambox ambox-move"):
            ma.replace_with('')
        for mama in soup.findAll('p', class_="mw-empty-elt"):
            mama.replace_with('')
        for mam in soup.findAll('sup', class_="reference"):
            mam.replace_with('')
            
        alt_list= []
        
        namez = soup.find('h1')
        anamez = (namez.text)
        alt_list.append(anamez)
        
        table = soup.find_all('table')
        info = table[0]
        rows = info.find_all('tr')
        para = soup.find_all('p')
        apara = (para[0].text)
        alt_list.append(apara)
        
        for row in rows:
            try:
                cells = row.find_all('td')
                # print contents of the second cell in the row
                acells = ( cells[1].text )
                alt_list.append(acells)
            except:
                pass
        linkk = ('https://en.wikipedia.org' + page_url)
        alt_list.append(linkk)
        
        print(alt_list)
        
        return alt_list
    except:
        print(page_url + ' is missing something!')
    
# call the function for each URL in the list
for linkkzz in link_list:
    get_info(linkkzz)
# Out:
# ['Activated charcoal cleanse', "Activated charcoal cleanses, also known as charcoal detoxes, are a pseudoscientific use of a proven medical intervention. Activated charcoal is available in powder, tablet and liquid form. Its proponents claim the use of activated charcoal on a regular basis will detoxify and cleanse the body as well as boost one's energy and brighten the skin. Such claims violate basic principles of chemistry and physiology. There is no medical evidence for any health benefits of cleanses or detoxes via activated charcoal or any other method. Charcoal, when ingested, will absorb vitamins and nutrients as well as prescription medications present in the gastrointestinal tract which can make it dangerous to use unless directed by a medical doctor.\n", 'https://en.wikipedia.org/wiki/Activated_charcoal_cleanse']
# ...

# %%
csvfile = open('alternative.csv', 'w', newline='', encoding='utf-8')
al = csv.writer(csvfile)
al.writerow(['Name', 'Info1','Link'])
link_list = ['/wiki/Activated_charcoal_cleanse','/wiki/Acupressure','/wiki/Acupuncture','/wiki/Affirmative_prayer','/wiki/Alexander_technique','/wiki/Alternative_cancer_treatments','/wiki/Animal-Assisted_Therapy','/wiki/Anthroposophical_medicine','/wiki/Apitherapy','/wiki/Applied_kinesiology','/wiki/Aquatherapy','/wiki/Aromatherapy','/wiki/Art_Therapy','/wiki/Asahi_Health','/wiki/Astrology','/wiki/Attachment_therapy','/wiki/Auriculotherapy','/wiki/Autogenic_training','/wiki/Autosuggestion','/wiki/Ayurveda','/wiki/Bach_flower_remedies','/wiki/Balneotherapy','/wiki/Bates_method','/wiki/Bibliotherapy','/wiki/Biodanza','/wiki/Bioresonance_therapy','/wiki/Blood_irradiation_therapies','/wiki/Body_work_(alternative_medicine)','/wiki/Chelation_therapy','/wiki/Chinese_food_therapy','/wiki/Chinese_herbology','/wiki/Chinese_martial_arts','/wiki/Traditional_Chinese_medicine','/wiki/Chinese_pulse_diagnosis','/wiki/Chakra','/wiki/Chiropractic','/wiki/Chromotherapy','/wiki/Colorpuncture','/wiki/Cinema_therapy','/wiki/Coding
','/wiki/Tibetan_eye_chart','/wiki/Traditional_Korean_medicine','/wiki/Traditional_Japanese_medicine','/wiki/Traditional_Mongolian_medicine','/wiki/Traditional_Tibetan_medicine','/wiki/Trager_approach','/wiki/Transcendental_meditation','/wiki/Trigger_point','/wiki/Tui_na','/wiki/Unani_medicine','/wiki/Urine_therapy','/wiki/Uropathy','/wiki/Vaginal_steaming','/wiki/Visualization_(cam)','/wiki/Mental_image','/wiki/Water_cure_(therapy)','/wiki/Wellness_(alternative_medicine)','/wiki/Wuxing_(Chinese_philosophy)','/wiki/Yoga_(alternative_medicine)','/wiki/R%C4%81ja_yoga','/wiki/Ashtanga_vinyasa_yoga','/wiki/Bikram_yoga','/wiki/Hatha_yoga','/wiki/Iyengar_yoga','/wiki/Kundalini_yoga','/wiki/Siddha_yoga','/wiki/Sivananda_yoga','/wiki/Tantric_yoga','/wiki/Viniyoga','/wiki/Vinyasa_yoga','/wiki/Yoga_Therapy','/wiki/Daoyin','/wiki/Zang-fu']
for linkkzz in link_list:
    try:
        new_row = get_info(linkkzz)
        al.writerow(new_row)
    except:
        pass
    
csvfile.close
# Out:
# ['Activated charcoal cleanse', "Activated charcoal cleanses, also known as charcoal detoxes, are a pseudoscientific use of a proven medical intervention. Activated charcoal is available in powder, tablet and liquid form. Its proponents claim the use of activated charcoal on a regular basis will detoxify and cleanse the body as well as boost one's energy and brighten the skin. Such claims violate basic principles of chemistry and physiology. There is no medical evidence for any health benefits of cleanses or detoxes via activated charcoal or any other method. Charcoal, when ingested, will absorb vitamins and nutrients as well as prescription medications present in the gastrointestinal tract which can make it dangerous to use unless directed by a medical doctor.\n", 'https://en.wikipedia.org/wiki/Activated_charcoal_cleanse']
# ...

# %%
#get the information for one herbal medicine
start ="https://www.nccih.nih.gov/health/acai"
page = requests.get(start)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
title = soup.find('h1')
print(title.text)
common = soup.find('div', class_= 'Commonnames-module--commonnames--2pIOh')
print(common.text)
for coco in soup.findAll('h2',  class_= "Blockheading-module--removealltopspace--zVMAM"):
    coco.replace_with('')
    back = soup.find('div', class_= 'Blockone-module--mainblock--2OhNz')
print(back.text)
# Out:
# Acai
# Common Names:Â acai, acai berry, aÃ§aÃ­
#
# The acai palm tree, native to tropical Central and South America, produces a deep purple fruit. The acai fruit has long been an important food source for indigenous peoples of the Amazon region.
# Acai products have become popular in the United States, where they have been promoted for weight-loss and anti-aging purposes.
# The Federal Trade Commission has taken action against companies that marketed acai weight-loss products in allegedly deceptive ways.
# Acai fruit pulp has been used experimentally as an oral contrast agent for magnetic resonance imaging (MRI) of the digestive tract.

# %%
start ="https://www.nccih.nih.gov/health/herbsataglance"
page = requests.get(start)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
list2_list = soup.select('li>a')
for linkz in list2_list:
    link2_list = []
    rel2 = (linkz.attrs['href'])
    link2_list.append(rel2)
    print(link2_list)
# Out:
# ['https://www.hhs.gov/']
# ['https://www.nih.gov/']
# ['#']
# ['#']
# ['#']
# ['#']
# ['#']
# ['#']
# ['#']
# ['#']
# ['#']
# ['#']
# ['#']
# ['#']
# ['/']
# ['/health']
# ['/health/acai']
# ['/health/aloe-vera']
# ['/health/asian-ginseng']
# ['/health/astragalus']
# ['/health/bilberry']
# ['/health/bitter-orange']
# ['/health/black-cohosh']
# ['/health/bromelain']
# ['/health/butterbur']
# ['/health/cats-claw']
# ['/health/chamomile']
# ['/health/chasteberry']
# ['/health/cinnamon']
# ['/health/cranberry']
# ['/health/dandelion']
# ['/health/echinacea']
# ['/health/elderberry']
# ['/health/ephedra']
# ['/health/european-mistletoe']
# ['/health/evening-primrose-oil']
# ['/health/fenugreek']
# ['/health/feverfew']
# ['/health/flaxseed-and-flaxseed-oil']
# ['/health/garcinia-cambogia']
# ['/health/garlic']
# ['/health/ginger']
# ['/health/ginkgo']
# ['/health/goldenseal']
# ['/health/grape-seed-extract']
# ['/health/green-tea']
# ['/health/hawthorn']
# ['/health/hoodia']
# ...

# %%
#Now get the data from multiple pages 
linkz2_list = ['/health/acai','/health/aloe-vera','/health/asian-ginseng','/health/astragalus','/health/bilberry','/health/bitter-orange','/health/black-cohosh','/health/bromelain','/health/butterbur','/health/cats-claw','/health/chamomile','/health/chasteberry','/health/cinnamon','/health/cranberry','/health/dandelion','/health/echinacea','/health/elderberry','/health/ephedra','/health/european-mistletoe','/health/evening-primrose-oil','/health/fenugreek','/health/feverfew','/health/flaxseed-and-flaxseed-oil','/health/garcinia-cambogia','/health/garlic','/health/ginger','/health/ginkgo','/health/goldenseal','/health/grape-seed-extract','/health/green-tea','/health/hawthorn','/health/hoodia','/health/horse-chestnut','/health/kava','/health/lavender','/health/licorice-root','/health/milk-thistle','/health/mugwort','/health/noni','/health/passionflower','/health/peppermint-oil','/health/pomegranate','/health/red-clover','/health/rhodiola','/health/sage','/health/saw-palmetto','/health/soy','/health/st-johns-wort','/health/tea-tree-oil','/health/thunder-god-vine','/health/turmeric','/health/valerian','/health/yohimbe']
def get_info(page_url):
    page = requests.get( 'https://www.nccih.nih.gov' + page_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    try:
        title = soup.find('h1')
        print(title.text)
        common = soup.find('div', class_= 'Commonnames-module--commonnames--2pIOh')
        print(common.text)
        for coco in soup.findAll('h2',  class_= "Blockheading-module--removealltopspace--zVMAM"):
            coco.replace_with('')
        back = soup.find('div', class_= 'Blockone-module--mainblock--2OhNz')
        print(back.text)
        linkkz = ('https://www.nccih.nih.gov' + page_url)
        print(linkkz)
    except:
        print(page_url + ' is missing something!')

# call the function for each URL in the list
for linkzzz in linkz2_list:
    get_info(linkzzz)
    
len(linkz2_list)
# Out:
# Acai
# Common Names:Â acai, acai berry, aÃ§aÃ­
#
# The acai palm tree, native to tropical Central and South America, produces a deep purple fruit. The acai fruit has long been an important food source for indigenous peoples of the Amazon region.
# Acai products have become popular in the United States, where they have been promoted for weight-loss and anti-aging purposes.
# The Federal Trade Commission has taken action against companies that marketed acai weight-loss products in allegedly deceptive ways.
# Acai fruit pulp has been used experimentally as an oral contrast agent for magnetic resonance imaging (MRI) of the digestive tract.
#
#
# https://www.nccih.nih.gov/health/acai
# Aloe Vera
# Common Names:Â aloe
#
# Aloe is a cactus-like plant that grows in hot, dry climates. It is cultivated in subtropical regions around the world, including the southern border areas of Texas, New Mexico, Arizona, and California.
# ...

# %%
#
linkz2_list = ['/health/acai','/health/aloe-vera','/health/asian-ginseng','/health/astragalus','/health/bilberry','/health/bitter-orange','/health/black-cohosh','/health/bromelain','/health/butterbur','/health/cats-claw','/health/chamomile','/health/chasteberry','/health/cinnamon','/health/cranberry','/health/dandelion','/health/echinacea','/health/elderberry','/health/ephedra','/health/european-mistletoe','/health/evening-primrose-oil','/health/fenugreek','/health/feverfew','/health/flaxseed-and-flaxseed-oil','/health/garcinia-cambogia','/health/garlic','/health/ginger','/health/ginkgo','/health/goldenseal','/health/grape-seed-extract','/health/green-tea','/health/hawthorn','/health/hoodia','/health/horse-chestnut','/health/kava','/health/lavender','/health/licorice-root','/health/milk-thistle','/health/mugwort','/health/noni','/health/passionflower','/health/peppermint-oil','/health/pomegranate','/health/red-clover','/health/rhodiola','/health/sage','/health/saw-palmetto','/health/soy','/health/st-johns-wort','/health/tea-tree-oil','/health/thunder-god-vine','/health/turmeric','/health/valerian','/health/yohimbe']
def get_info(page_url):
    page = requests.get( 'https://www.nccih.nih.gov' + page_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    try:
        herb_list =[]
        title = soup.find('h1')
        herb_list.append(title.text)
        
        common = soup.find('div', class_= 'Commonnames-module--commonnames--2pIOh')
        herb_list.append(common.text)
        
        for coco in soup.findAll('h2',  class_= "Blockheading-module--removealltopspace--zVMAM"):
            coco.replace_with('')
        back = soup.find('div', class_= 'Blockone-module--mainblock--2OhNz')
        herb_list.append(back.text)
        
        linkkz = ('https://www.nccih.nih.gov' + page_url)
        herb_list.append(linkkz)
        
        print(herb_list)
        return herb_list
    except:
        print(page_url + ' is missing something!')

# call the function for each URL in the list
for linkzzz in linkz2_list:
    get_info(linkzzz)
# Out:
# ['Acai', 'Common Names:Â\xa0acai, acai berry, aÃ§aÃ\xad', '\nThe acai palm tree, native to tropical Central and South America, produces a deep purple fruit. The acai fruit has long been an important food source for indigenous peoples of the Amazon region.\nAcai products have become popular in the United States, where they have been promoted for weight-loss and anti-aging purposes.\nThe Federal Trade Commission has taken action against companies that marketed acai weight-loss products in allegedly deceptive ways.\nAcai fruit pulp has been used experimentally as an oral contrast agent for magnetic resonance imaging (MRI) of the digestive tract.\n\n', 'https://www.nccih.nih.gov/health/acai']
# ...

# %%
csvfile = open('herb.csv', 'w', newline='', encoding='utf-8')
h = csv.writer(csvfile)
h.writerow(['Name', 'Info1','Info2','Link'])
linkz2_list = ['/health/acai','/health/aloe-vera','/health/asian-ginseng','/health/astragalus','/health/bilberry','/health/bitter-orange','/health/black-cohosh','/health/bromelain','/health/butterbur','/health/cats-claw','/health/chamomile','/health/chasteberry','/health/cinnamon','/health/cranberry','/health/dandelion','/health/echinacea','/health/elderberry','/health/ephedra','/health/european-mistletoe','/health/evening-primrose-oil','/health/fenugreek','/health/feverfew','/health/flaxseed-and-flaxseed-oil','/health/garcinia-cambogia','/health/garlic','/health/ginger','/health/ginkgo','/health/goldenseal','/health/grape-seed-extract','/health/green-tea','/health/hawthorn','/health/hoodia','/health/horse-chestnut','/health/kava','/health/lavender','/health/licorice-root','/health/milk-thistle','/health/mugwort','/health/noni','/health/passionflower','/health/peppermint-oil','/health/pomegranate','/health/red-clover','/health/rhodiola','/health/sage','/health/saw-palmetto','/health/soy','/health/st-johns-wort','/health/tea-tree-oil','/health/thunder-god-vine','/health/turmeric','/health/valerian','/health/yohimbe']

for linkkzzz in linkz2_list:
    try:
        neww_row = get_info(linkkzzz)
        h.writerow(neww_row)
    except:
        pass
    
csvfile.close
# Out:
# ['Acai', 'Common Names:Â\xa0acai, acai berry, aÃ§aÃ\xad', '\nThe acai palm tree, native to tropical Central and South America, produces a deep purple fruit. The acai fruit has long been an important food source for indigenous peoples of the Amazon region.\nAcai products have become popular in the United States, where they have been promoted for weight-loss and anti-aging purposes.\nThe Federal Trade Commission has taken action against companies that marketed acai weight-loss products in allegedly deceptive ways.\nAcai fruit pulp has been used experimentally as an oral contrast agent for magnetic resonance imaging (MRI) of the digestive tract.\n\n', 'https://www.nccih.nih.gov/health/acai']
# ...

# %%
start ="http://www.gemologyproject.com/wiki/index.php?title=Amethyst"
page = requests.get(start)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
title3 = soup.find('h1')
print(title3.text)
about = soup.find_all('p')
print(about[1].text)
# Out:
# Amethyst
# Amethyst is a purple variety of the mineral quartz. It occurs in all intensities of the color purple from a light pastel to a depth of royal splendor. Until the beginning of the 20th century it was quite rare and costly. When vast deposits were found in Brazil, amethyst became very accessible and affordable. Amethyst has always been linked to the thinking process, ensuring clarity of vision. It inspires creativity, courage and valor.
# Amethyst has been successfully synthesized in the lab, so buyers need to be sure their source is qualified to separate natural from lab grown material.

# %%
start ="http://www.gemologyproject.com/wiki/index.php?title=Alphabetic_list_by_gemstone_name"
page = requests.get(start)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
#scrape all pages, select ten to include 
list3_list = soup.select('p>a')
for linkzz in list3_list:
    link3_list = []
    rel3 = (linkzz.attrs['href'])
    link3_list.append(rel3)
    print(link3_list)
# Out:
# ['/wiki/index.php?title=Achroite']
# ['/wiki/index.php?title=Agate']
# ['/wiki/index.php?title=Akoya_Pearl&action=edit&redlink=1']
# ['/wiki/index.php?title=Alexandrite']
# ['/wiki/index.php?title=Almandine']
# ['/wiki/index.php?title=Amazonite']
# ['/wiki/index.php?title=Amber']
# ['/wiki/index.php?title=Amethyst']
# ['/wiki/index.php?title=Ametrine']
# ['/wiki/index.php?title=Ammolite']
# ['/wiki/index.php?title=Anatase']
# ['/wiki/index.php?title=Andalusite']
# ['/wiki/index.php?title=Andesine']
# ['/wiki/index.php?title=Andradite']
# ['/wiki/index.php?title=Apatite']
# ['/wiki/index.php?title=Aquamarine']
# ['/wiki/index.php?title=Arkansas_stone']
# ['/wiki/index.php?title=Axinite']
# ['/wiki/index.php?title=Azurite']
# ['/wiki/index.php?title=Barite']
# ['/wiki/index.php?title=Beryl']
# ['/wiki/index.php?title=Benitoite']
# ['/wiki/index.php?title=Bi-color']
# ['/wiki/index.php?title=Bixbite']
# ['/wiki/index.php?title=Bloodstone']
# ['/wiki/index.php?title=Bowenite']
# ...

# %%
linkz3_list = ['/wiki/index.php?title=Amethyst','/wiki/index.php?title=Agate','/wiki/index.php?title=Ruby','/wiki/index.php?title=Rock_Crystal','/wiki/index.php?title=Chrysoberyl','/wiki/index.php?title=Citrine','/wiki/index.php?title=Coral','/wiki/index.php?title=Quartz','/wiki/index.php?title=Diamond', '/wiki/index.php?title=Azurite']
def get_info(page_url):
    page = requests.get( 'http://www.gemologyproject.com' + page_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    try:
        for cococo in soup.findAll('table'):
            cococo.replace_with('')
        title3 = soup.find('h1')
        print(title3.text)
        about = soup.find_all('p')
        print(about[0].text)
        print(about[1].text)
        linkkzz = ('http://www.gemologyproject.com' + page_url)
        print(linkkzz)
    except:
        pass

# call the function for each URL in the list
for linkzzzz in linkz3_list:
    get_info(linkzzzz)
# Out:
# Amethyst
# Amethyst is a purple variety of the mineral quartz. It occurs in all intensities of the color purple from a light pastel to a depth of royal splendor. Until the beginning of the 20th century it was quite rare and costly. When vast deposits were found in Brazil, amethyst became very accessible and affordable. Amethyst has always been linked to the thinking process, ensuring clarity of vision. It inspires creativity, courage and valor.
# Amethyst has been successfully synthesized in the lab, so buyers need to be sure their source is qualified to separate natural from lab grown material.
#
# Amethyst is a type I stone in the GIA clarity grading system is usually free from eye visible inclusions.
# Typical inclusions visible with magnification are:
#
# http://www.gemologyproject.com/wiki/index.php?title=Amethyst
# Agate
# ...

# %%
linkz3_list = ['/wiki/index.php?title=Amethyst','/wiki/index.php?title=Agate','/wiki/index.php?title=Ruby','/wiki/index.php?title=Rock_Crystal','/wiki/index.php?title=Chrysoberyl','/wiki/index.php?title=Citrine','/wiki/index.php?title=Coral','/wiki/index.php?title=Quartz','/wiki/index.php?title=Diamond', '/wiki/index.php?title=Azurite']
def get_info(page_url):
    page = requests.get( 'http://www.gemologyproject.com' + page_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    try:
        gem_list=[]
        for cococo in soup.findAll('table'):
            cococo.replace_with('')
        title3 = soup.find('h1')
        gem_list.append(title3.text)
        
        about = soup.find_all('p')
        gem_list.append(about[0].text)
        gem_list.append(about[1].text)
        linkkzz = ('http://www.gemologyproject.com' + page_url)
        gem_list.append(linkkzz)
        
        return gem_list
    except:
        pass

# call the function for each URL in the list
for linkzzzz in linkz3_list:
    get_info(linkzzzz)

# %%
csvfile = open('gem.csv', 'w', newline='', encoding='utf-8')
g = csv.writer(csvfile)
g.writerow(['Name', 'Info1','Info2','Link'])
linkz3_list = ['/wiki/index.php?title=Amethyst','/wiki/index.php?title=Agate','/wiki/index.php?title=Ruby','/wiki/index.php?title=Rock_Crystal','/wiki/index.php?title=Chrysoberyl','/wiki/index.php?title=Citrine','/wiki/index.php?title=Coral','/wiki/index.php?title=Quartz','/wiki/index.php?title=Diamond', '/wiki/index.php?title=Azurite']

for linkzzzz in linkz3_list:
    try:
        newww_row = get_info(linkzzzz)
        g.writerow(newww_row)
    except:
        pass
    
csvfile.close
# Out:
# <function TextIOWrapper.close()>
